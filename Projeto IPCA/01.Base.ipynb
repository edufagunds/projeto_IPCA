# %%
import pandas as pd
import numpy as np

# %%
url = r'C:\Users\PC\Desktop\Projetos\Python\Projeto IPCA\tabela7060_2023_2024.xlsx'

dados = pd.read_excel(url, skiprows=2, nrows=4512)

# %%
dados.tail()
# Out:
#                 Mês Geral, grupo, subgrupo, item e subitem Rio Branco (AC)  \
# 4507  dezembro 2024                        1201048.Cerveja               0
# 4508  dezembro 2024      1201051.Outras bebidas alcoólicas               -
# 4509  dezembro 2024                          1201052.Vinho               -
# 4510  dezembro 2024                          1201061.Doces               -
# 4511  dezembro 2024                        1201088.Sorvete            0.18
#
#      São Luís (MA) Aracaju (SE) Campo Grande (MS) Goiânia (GO) Brasília (DF)  \
# 4507             0         0.04              0.62        -0.11         -0.18
# 4508          1.91            -              1.83            -             -
# 4509             -            -                 -            -             -
# 4510             -         0.51                 -         0.83             -
# 4511             -         1.02              0.95         2.45             -
#
#      RM de Belém (PA) RM de Fortaleza (CE) RM de Recife (PE)  \
# 4507            -0.47                 1.03              0.54
# 4508                -                    -               0.7
# 4509                -                    -                 -
# 4510                -                    -                 -
# 4511                -                  0.5                 -
#
#      RM de Salvador (BA) RM de Belo Horizonte (MG) RM da Grande Vitória (ES)  \
# 4507                 0.1                     -1.42                     -0.22
# 4508                   -                         -                     -0.17
# 4509                   -                         -                         -
# 4510                   -                         -                         -
# 4511                 0.5                         -                         -
#
#      RM do Rio de Janeiro (RJ) RM de São Paulo (SP) RM de Curitiba (PR)  \
# 4507                       0.7                 0.53                1.01
# 4508                         -                    -                   -
# 4509                      3.87                    -                   -
# 4510                         -                    -                   -
# 4511                         -                 0.95                1.61
#
#      RM de Porto Alegre (RS)
# 4507                    0.82
# 4508                       -
# 4509                       -
# 4510                       -
# 4511                       -

# %% [markdown]
# # Tratamentos
#
#     - alterar nome das colunas:
#         - 'Geral, grupo, subgrupo, item e subitem' para Items
#         - Coluna de estados apenas para siglas
#         - Meses para apenas meses do ano
#     - tratar nomes de dados:
#         - coluna de items para apenas os nomes, sem numeros
#     - tratar valores:
#         - trocar vazios para 0.0
#         - mudar para float64

# %%
# tratando nome de colunas
dados = dados.rename(columns={
       'Geral, grupo, subgrupo, item e subitem': 'Itens', 
       'Rio Branco (AC)' : 'AC',
       'São Luís (MA)':'MA', 
       'Aracaju (SE)':'SE',
       'Campo Grande (MS)':'MS', 
       'Goiânia (GO)':'GO', 
       'Brasília (DF)':'DF',
       'RM de Belém (PA)': 'PA',
       'RM de Fortaleza (CE)' : 'CE',
       'RM de Recife (PE)' : 'PE',
       'RM de Salvador (BA)' : 'BA',
       'RM de Belo Horizonte (MG)' : 'MG',
       'RM da Grande Vitória (ES)' : 'ES',
       'RM do Rio de Janeiro (RJ)' : 'RJ',
       'RM de São Paulo (SP)' : 'SP', 
       'RM de Curitiba (PR)' : 'PR',
       'RM de Porto Alegre (RS)' : 'RS'                
                              })

# %%
# tratando coluna de itens
# ^: indica o início da string.
# \d+: corresponde a um ou mais dígitos.
dados['Itens'] = dados['Itens'].str.replace('^\d+\.', '', regex=True)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\PC\AppData\Local\Temp\ipykernel_15972\2871686057.py:4: SyntaxWarning: invalid escape sequence '\d'
#   dados['Itens'] = dados['Itens'].str.replace('^\d+\.', '', regex=True)

# %%
# tratando valores nulos e alterando tipo para format
col_numericas = list(dados.columns)

dados[col_numericas[2:]] = dados[col_numericas[2:]].apply(lambda x: x.replace('-', '0.0')).astype(np.float64)

# %%
# preciso excluir os dados que podem poluir a analise, ex.:Alimentação e bebidas que é a media desse grupo ou Cereais, leguminosas e oleaginosas
dados['Itens'].unique().tolist()

exclusao = [
'Alimentação e bebidas',
'Cereais, leguminosas e oleaginosas',
'Farinhas, féculas e massas',
'Açúcares e derivados',
'Hortaliças e verduras',
'Frutas',
'Carnes',
'Pescados',
'Carnes e peixes industrializados', 
'Aves e ovos',
'Leites e derivados',
'Panificados',
'Óleos e gorduras',
'Bebidas e infusões',
'Enlatados e conservas',
'Sal e condimentos',
'Alimentação fora do domicílio'
]

df = dados.query('Itens not in @exclusao')

# %%
# alterar tipo de meses

list(dados['Mês'].unique())

meses_conversao = {
 'janeiro 2023'   : '2023-01'  ,
 'fevereiro 2023' : '2023-02'  ,
 'março 2023'     : '2023-03'  ,
 'abril 2023'     : '2023-04'  ,
 'maio 2023'      : '2023-05'  ,
 'junho 2023'     : '2023-06'  ,
 'julho 2023'     : '2023-07'  ,
 'agosto 2023'    : '2023-08'  ,
 'setembro 2023'  : '2023-09'  ,
 'outubro 2023'   : '2023-10'  ,
 'novembro 2023'  : '2023-11'  ,
 'dezembro 2023'  : '2023-12'  ,
 'janeiro 2024'   : '2024-01' ,
 'fevereiro 2024' : '2024-02' ,
 'março 2024'     : '2024-03' ,
 'abril 2024'     : '2024-04' ,
 'maio 2024'      : '2024-05' ,
 'junho 2024'     : '2024-06' ,
 'julho 2024'     : '2024-07' ,
 'agosto 2024'    : '2024-08' ,
 'setembro 2024'  : '2024-09' ,
 'outubro 2024'   : '2024-10' ,
 'novembro 2024'  : '2024-11' ,
 'dezembro 2024'  : '2024-12'
}

df['Mês'] = df['Mês'].replace(meses_conversao) # 
df['Mês'] = pd.to_datetime(df['Mês'], format='%Y-%m')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4080 entries, 1 to 4511
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mês     4080 non-null   datetime64[ns]
#  1   Itens   4080 non-null   object
#  2   AC      4080 non-null   float64
#  3   MA      4080 non-null   float64
#  4   SE      4080 non-null   float64
#  5   MS      4080 non-null   float64
#  6   GO      4080 non-null   float64
#  7   DF      4080 non-null   float64
#  8   PA      4080 non-null   float64
#  9   CE      4080 non-null   float64
#  10  PE      4080 non-null   float64
#  11  BA      4080 non-null   float64
#  12  MG      4080 non-null   float64
#  13  ES      4080 non-null   float64
#  14  RJ      4080 non-null   float64
#  15  SP      4080 non-null   float64
#  16  PR      4080 non-null   float64
#  17  RS      4080 non-null   float64
# dtypes: datetime64[ns](1), float64(16), object(1)
# memory usage: 605.6+ KB
# C:\Users\PC\AppData\Local\Temp\ipykernel_15972\1882563749.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mês'] = df['Mês'].replace(meses_conversao) #
# C:\Users\PC\AppData\Local\Temp\ipykernel_15972\1882563749.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mês'] = pd.to_datetime(df['Mês'], format='%Y-%m')

# %% [markdown]
# # Lista de Itens
#  - criar uma lista com itens de uma cesta e avalia-los

# %%
categorias = {

    'graos' :           ['Arroz', 'Feijão - carioca (rajado)', 'Farinha de mandioca', 'Farinha de trigo', 'Macarrão'],
    'hortalicas' :      ['Batata-inglesa', 'Tomate', 'Cebola', 'Alface', 'Cenoura', 'Couve', 'Pimentão'],
    'frutas' :          ['Banana - prata', 'Maçã', 'Laranja - pera', 'Mamão', 'Melancia'],
    'proteinas' :       ['Acém', 'Costela', 'Contrafilé', 'Alcatra', 'Carne de porco', 'Frango inteiro', 'Frango em pedaços', 'Ovo de galinha'], 
    'laticinios' :      ['Leite longa vida', 'Queijo', 'Iogurte e bebidas lácteas'],
    'oleos_gorduras' :  ['Manteiga', 'Margarina', 'Óleo de soja', 'Azeite de oliva'],
    'outros' :          ['Café moído', 'Café solúvel', 'Sal']

}

# caso eu queira visualizar o que tem em cada item
# for categoria, itens in categorias.items():
#     print(f'cagoria:{categoria}')
#     for item in itens:
#         print(f' - {item}')

# iteração de cada item (invertendo os valores do dicionario)
item_categoria = {item : categoria for categoria, itens in categorias.items() for item in itens}

# %%
# Filtrar apenas SP
ipca_sp = df[['Mês', 'Itens', 'SP']]

# filtrar apenas os itens presentes nas categorias
ipca_sp = ipca_sp[ipca_sp['Itens'].isin(item_categoria)]
ipca_sp = ipca_sp.reset_index(drop=True)

# transformar em long
ipca_sp_pivot = ipca_sp.pivot_table(
    index='Mês',
    columns='Itens',
    values='SP'
)

# incluir coluna total para linha
ipca_sp_pivot['Total_mensal'] = ipca_sp_pivot.sum(axis=1)

# incluir linha total para cada ano
total_ano = ipca_sp_pivot.groupby(ipca_sp_pivot.index.year).sum()
ipca_sp_pivot = ipca_sp_pivot = pd.concat([ipca_sp_pivot, total_ano])


# verificar qual item teve o maior impacto no indice
ipca_sp_pivot['Alimento_maior_inflacao'] = ipca_sp_pivot.drop(columns='Total_mensal').idxmax(axis=1)
ipca_sp_pivot['Alimento_menor_inflacao'] = ipca_sp_pivot.drop(columns=['Total_mensal', 'Alimento_maior_inflacao']).idxmin(axis=1)

ipca_sp_pivot
# Out:
# Itens                 Acém  Alcatra  Alface  Arroz  Azeite de oliva  \
# Mês
# 2023-01-01 00:00:00  -2.45    -1.78   11.38   2.44             1.19
# 2023-02-01 00:00:00  -3.05    -2.59    9.64   1.11            -0.25
# 2023-03-01 00:00:00   1.10    -1.87    7.24   1.20             2.13
# 2023-04-01 00:00:00  -1.79    -2.82    0.69  -0.69             0.54
# 2023-08-01 00:00:00    2.28  0.0   -8.89         -2.07        -77.25
# 2023-09-01 00:00:00   -2.08  0.0    3.95         -3.02        -64.02
# 2023-10-01 00:00:00   -0.46  0.0    2.75          0.05         47.01
# 2023-11-01 00:00:00    1.43  0.0   -3.56         -0.77         42.55
# 2023-12-01 00:00:00   -2.12  0.0    8.88          3.13         88.11
# 2024-01-01 00:00:00    2.84  0.0   -5.47          3.45         70.70
# 2024-02-01 00:00:00   -1.12  0.0    6.55         -0.50         60.34
# 2024-03-01 00:00:00   -3.68  0.0    5.88          0.14         57.86
# 2024-04-01 00:00:00   -0.57  0.0   19.41         -0.02         81.75
# 2024-05-01 00:00:00   -2.00  0.0  -10.55          0.15          9.48
# 2024-06-01 00:00:00    1.28  0.0   13.15          0.17        -15.16
# 2024-07-01 00:00:00   -1.86  0.0  -29.94          0.26       -112.55
# 2024-08-01 00:00:00    1.71  0.0  -16.89          1.58        -28.09
# 2024-09-01 00:00:00    0.51  0.0   -3.11          2.54         31.80
# 2024-10-01 00:00:00    0.94  0.0    8.78          4.51         17.49
# 2024-11-01 00:00:00    1.19  0.0   -1.48         11.50         92.17
# 2024-12-01 00:00:00    1.82  0.0   -5.84          6.30         32.84
# 2023                   6.28  0.0    3.82        -34.22         74.32
# 2024                   1.06  0.0  -19.51         30.08        298.63
#
# Itens                Alimento_maior_inflacao    Alimento_menor_inflacao
# Mês
# 2023-01-01 00:00:00           Batata-inglesa                     Cebola
# 2023-02-01 00:00:00                  Cenoura                     Tomate
# 2023-03-01 00:00:00                  Cenoura             Batata-inglesa
# 2023-04-01 00:00:00                 Pimentão             Banana - prata
# 2023-05-01 00:00:00                   Tomate                      Mamão
# 2023-06-01 00:00:00           Batata-inglesa               Óleo de soja
# 2023-07-01 00:00:00           Banana - prata  Feijão - carioca (rajado)
# 2023-08-01 00:00:00           Banana - prata             Batata-inglesa
# 2023-09-01 00:00:00                     Maçã                    Cenoura
# 2023-10-01 00:00:00                   Cebola           Leite longa vida
# 2023-11-01 00:00:00                   Cebola                      Mamão
# 2023-12-01 00:00:00           Batata-inglesa                     Queijo
# 2024-01-01 00:00:00                  Cenoura                      Mamão
# 2024-02-01 00:00:00                  Cenoura                   Pimentão
# 2024-03-01 00:00:00                   Cebola                    Cenoura
# 2024-04-01 00:00:00                    Mamão             Batata-inglesa
# 2024-05-01 00:00:00                   Cebola                     Tomate
# 2024-06-01 00:00:00           Batata-inglesa                      Mamão
# 2024-07-01 00:00:00               Café moído                     Tomate
# 2024-08-01 00:00:00                    Mamão             Batata-inglesa
# 2024-09-01 00:00:00                    Mamão                     Cebola
# 2024-10-01 00:00:00                     Acém                      Mamão
# 2024-11-01 00:00:00             Óleo de soja           Leite longa vida
# 2024-12-01 00:00:00                  Alcatra                   Pimentão
# 2023                         Azeite de oliva               Óleo de soja
# 2024                          Laranja - pera                     Tomate
#
# [26 rows x 38 columns]
